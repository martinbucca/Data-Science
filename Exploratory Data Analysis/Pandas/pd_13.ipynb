# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Nombrar la aplicación que lleva más tiempo sin ser actualizada. (⭐)

# %% [markdown]
# Descarto las filas que no tienen un formato de Fecha valido (eg: '1.0.19'), considerando formato valido a '%B %d, %Y'

# %%
import pandas as pd
path = '/content/drive/MyDrive/Organizacion de datos/TP1 - Pandas, Spark y Visualización de datos/googleplaystore.csv'
df = pd.read_csv(path, usecols=['App', 'Last Updated'])
df['Last Updated'] = pd.to_datetime(df['Last Updated'], format='%B %d, %Y', errors='coerce')
df.dropna(subset='Last Updated', inplace=True)
most_time_without_update_index = df['Last Updated'].idxmin()
df.loc[most_time_without_update_index, 'App']
# Out:
# 'FML F*ck my life + widget'
